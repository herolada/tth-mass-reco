# %%
import collections
import csv
import keras
import keras.backend as K
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import tensorflow as tf
import time
import shap
import ROOT as root
from sklearn.preprocessing import StandardScaler

from keras import optimizers
from keras.regularizers import l2

from keras.layers import Dense, LayerNormalization, BatchNormalization, Dropout, GaussianNoise, Activation, Add
from keras import activations

from ROOT import TFile, TLorentzVector

from tools.constants import *

# %%
""" Data augmentation. """
def random_rotation(X,deltas_phi,num_vectors,met):

    for i in range(num_vectors):
        
        R = np.sqrt((X[:,4*i+0]**2 + X[:,4*i+1]**2))
        old_phis = np.arctan2(X[:,4*i+1],X[:,4*i+0])
        new_phis = old_phis + deltas_phi

        angles_sin = np.sin(new_phis)
        angles_cos = np.cos(new_phis)

        X[:,4*i+0] = angles_cos * R
        X[:,4*i+1] = angles_sin * R
        
    if met:
        return random_rotation_MET(X, deltas_phi)
    else:
        return X


def random_rotation_MET(X, deltas_phi):

    R = np.sqrt((X[:,-11]**2 + X[:,-10]**2))
    old_phis = np.arctan2(X[:,-10],(X[:,-11]))
    new_phis = old_phis + deltas_phi

    angles_sin = np.sin(new_phis)
    angles_cos = np.cos(new_phis)

    X[:,-11] = angles_cos * R
    X[:,-10] = angles_sin * R

    return X


def data_rotation(X, y, num_vectors_X = 11, num_vectors_y = 1, met = True):  
    
    deltas_phi = np.random.rand(X.shape[0])*2*math.pi
    X = random_rotation(X,deltas_phi,num_vectors_X,met)
    y = random_rotation(y,deltas_phi,num_vectors_y,False)
        
    return X,y

""" Data generator for serving the NN data. """
# modified from source: https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, X, y, scaler = ["scaler_params/X_scaler_mass_reco_narrow_btags.csv","scaler_params/y_scaler_higgs_mse_btags.csv"], batch_size=32, n_features=72, shuffle=True, augmentation = True, ceil = False):
        self.n_features = n_features
        self.batch_size = batch_size
        self.X = X
        self.y = y
        self.shuffle = shuffle
        self.augmentation = augmentation
        self.ceil = ceil
        self.indexes = np.arange(len(X))
        with open(scaler[0]) as f:
            scaler_params = np.loadtxt(f, delimiter=",")
            self.X_scaler = scaler_params[0:2,:]
        with open(scaler[1]) as f:
            scaler_params = np.loadtxt(f, delimiter=",")
            self.y_scaler = scaler_params[0:2,:]
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        if self.ceil:
            return int(np.ceil(len(self.X) / self.batch_size))
        return int(np.floor(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Generate data
        X, y, weights = self.__data_generation(indexes)
        return X, y, weights

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, indexes):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)

        X = self.X[indexes]

        weights = X[:,-1]
        X = X[:,:-1]

        y = self.y[indexes]

        if self.augmentation:
            X,y = data_rotation(X, y, num_vectors_X = 11, num_vectors_y = 1, met = True)
        X = (X-self.X_scaler[0])/self.X_scaler[1]     # Standardize
        y = (y-self.y_scaler[0])/self.y_scaler[1]     # Standardize

        return X, y, weights
    
    def get_all(self):
        'Get all data - all batches.'
        X = []
        y = []

        for i in range(self.__len__()):
            X_y = self.__getitem__(i)
            X += X_y[0].tolist()
            y += X_y[1].tolist()

        X = np.array(X)
        y = np.array(y)
        
        return X, y

# %%
# Load data.

def add_weights(tth,ttz):
    """ Class weights, because of the imbalance between the productions' number of events. """
    weight_tth = 1/(2*len(tth)/(len(ttz)+len(tth)))
    weight_ttz = 1/(2*len(ttz)/(len(ttz)+len(tth)))

    print(weight_tth)
    print(weight_ttz)

    ones = np.ones((tth.shape[0],1))
    tth = np.concatenate((tth, weight_tth*ones),axis=1)

    ones = np.ones((ttz.shape[0],1))
    ttz = np.concatenate((ttz, weight_ttz*ones),axis=1)

    return tth,ttz

with open("data/mass_reco/mass_reco_input_narrow_selection_btags_train_ttH.csv") as f: 
    X_y_train_ttH = np.loadtxt(f, delimiter=",", skiprows=1)
with open("data/mass_reco/mass_reco_input_narrow_selection_btags_train_ttZ.csv") as f: 
    X_y_train_ttZ = np.loadtxt(f, delimiter=",", skiprows=1)

with open("data/mass_reco/mass_reco_input_narrow_selection_btags_test_ttH.csv") as f: 
    X_y_test_ttH = np.loadtxt(f, delimiter=",", skiprows=1)
with open("data/mass_reco/mass_reco_input_narrow_selection_btags_test_ttZ.csv") as f: 
    X_y_test_ttZ = np.loadtxt(f, delimiter=",", skiprows=1)

with open("data/mass_reco/mass_reco_input_narrow_selection_btags_val_ttH.csv") as f: 
    X_y_val_ttH = np.loadtxt(f, delimiter=",", skiprows=1)
with open("data/mass_reco/mass_reco_input_narrow_selection_btags_val_ttZ.csv") as f: 
    X_y_val_ttZ = np.loadtxt(f, delimiter=",", skiprows=1)


X_y_train_ttH, X_y_train_ttZ = add_weights(X_y_train_ttH, X_y_train_ttZ)    # Add weights to the data
X_y_train = np.concatenate((X_y_train_ttH, X_y_train_ttZ), axis=0)          # Combine ttH and ttZ for training.
X_train = np.concatenate((X_y_train[:,:-10], X_y_train[:,-6:]), axis = 1)   # Seprate X ...
y_train = X_y_train[:,-10:-6]                                               # ... and y.


X_y_val_ttH, X_y_val_ttZ = add_weights(X_y_val_ttH, X_y_val_ttZ)    # Repeat for val and test...
X_y_val = np.concatenate((X_y_val_ttH, X_y_val_ttZ), axis=0)
X_val = np.concatenate((X_y_val[:,:-10], X_y_val[:,-6:]), axis = 1)   
y_val = X_y_val[:,-10:-6]

X_y_test_ttH, X_y_test_ttZ = add_weights(X_y_test_ttH, X_y_test_ttZ)
X_y_test = np.concatenate((X_y_test_ttH, X_y_test_ttZ), axis=0)
X_test = np.concatenate((X_y_test[:,:-10], X_y_test[:,-6:]), axis = 1)  
y_test = X_y_test[:,-10:-6]

num_features = X_train.shape[1]-1   # exclude weights
num_samples = X_train.shape[0]

print(num_features,num_samples)
# Out:
# 0.8002137488795421
# 1.3327400091869543
# 0.8011647254575707
# 1.330110497237569
# 0.8
# 1.3333333333333333
# 76 23211

# %%
train_generator = DataGenerator(X_train, y_train, n_features = num_features, batch_size=4096, shuffle=True, augmentation = True, ceil = False)
val_generator = DataGenerator(X_val, y_val, n_features = num_features, batch_size=128, shuffle=False, augmentation = False, ceil = True)
test_generator = DataGenerator(X_test, y_test, n_features = num_features, batch_size=128, shuffle=False, augmentation = False, ceil = True)

# %%
""" Get scaler params... """
""" X_train = np.empty((num_samples,num_features), dtype=float)
y_train = np.empty((num_samples,4), dtype=float)
c = 0

for i in range(len(train_generator)):
    rows = len(train_generator[i][0][:])

    X_train[c:c+rows,:] = train_generator[i][0][:]
    y_train[c:c+rows,:] = train_generator[i][1][:]
    c += rows

X_train = X_train[1:,:]
y_train = y_train[1:,:]
X_scaler = StandardScaler()
y_scaler = StandardScaler()
X_scaler = X_scaler.fit(X_train)
y_scaler = y_scaler.fit(y_train)

f = open("scaler_params/X_scaler_mass_reco_narrow.csv", "w")
writer = csv.writer(f)
writer.writerow(X_scaler.mean_)
writer.writerow(X_scaler.scale_)
f.close()

f = open("scaler_params/y_scaler_higgs_mse_btags.csv", "w")
writer = csv.writer(f)
writer.writerow(y_scaler.mean_)
writer.writerow(y_scaler.scale_)
f.close() """
# Out:
# ' X_train = np.empty((num_samples,num_features), dtype=float)\ny_train = np.empty((num_samples,4), dtype=float)\nc = 0\n\nfor i in range(len(train_generator)):\n    rows = len(train_generator[i][0][:])\n\n    X_train[c:c+rows,:] = train_generator[i][0][:]\n    y_train[c:c+rows,:] = train_generator[i][1][:]\n    c += rows\n\nX_train = X_train[1:,:]\ny_train = y_train[1:,:]\nX_scaler = StandardScaler()\ny_scaler = StandardScaler()\nX_scaler = X_scaler.fit(X_train)\ny_scaler = y_scaler.fit(y_train)\n\nf = open("scaler_params/X_scaler_mass_reco_narrow.csv", "w")\nwriter = csv.writer(f)\nwriter.writerow(X_scaler.mean_)\nwriter.writerow(X_scaler.scale_)\nf.close()\n\nf = open("scaler_params/y_scaler_higgs_mse_btags.csv", "w")\nwriter = csv.writer(f)\nwriter.writerow(y_scaler.mean_)\nwriter.writerow(y_scaler.scale_)\nf.close() '

# %%
""" Define NN architecture. """
def baseline_model(num_features):

    i = keras.Input(shape = (num_features,))
    dropout_1 = Dropout(0.2)(i)
    dense_1 = Dense(10*num_features, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_1)
    relu_1 = Activation(activations.relu)(dense_1)

    dropout_2 = Dropout(0.2)(relu_1)
    dense_2 = Dense(10*num_features, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_2)
    relu_2 = Activation(activations.relu)(dense_2)

    dropout_3 = Dropout(0.2)(relu_2)
    dense_3 = Dense(10*num_features, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_3)
    relu_3 = Activation(activations.relu)(dense_3)

    dropout_4 = Dropout(0.2)(relu_3)
    dense_4 = Dense(10*num_features, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_4)
    relu_4 = Activation(activations.relu)(dense_4)

    dropout_5 = Dropout(0.2)(relu_4)
    dense_5 = Dense(10*num_features, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_5)
    relu_5 = Activation(activations.relu)(dense_5)

    dropout_6 = Dropout(0.2)(relu_5)
    dense_6 = Dense(10*num_features, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_6)
    relu_6 = Activation(activations.relu)(dense_6)

    dropout_7 = Dropout(0.2)(relu_6)
    o = Dense(4, activation='linear', kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001))(dropout_7)

    model = keras.Model(i, o)
    model.compile(loss='mse', optimizer=optimizers.Adam(lr=0.0005, beta_1=0.9))
    model.summary()
    return model

def scheduler(epoch, lr):
    return lr * 0.99

# %%
""" Training. Callbacks used are learning rate decay and early stopping. """
model = baseline_model(num_features)
callback1 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
callback2 = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(x=train_generator, validation_data = val_generator, epochs=300, verbose=1, callbacks = [callback1, callback2])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 76)]              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 76)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 760)               58520
# _________________________________________________________________
# activation_6 (Activation)    (None, 760)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 760)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 760)               578360
# _________________________________________________________________
# activation_7 (Activation)    (None, 760)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 760)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 760)               578360
# _________________________________________________________________
# activation_8 (Activation)    (None, 760)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 760)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 760)               578360
# _________________________________________________________________
# activation_9 (Activation)    (None, 760)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 760)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 760)               578360
# _________________________________________________________________
# activation_10 (Activation)   (None, 760)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 760)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 760)               578360
# _________________________________________________________________
# activation_11 (Activation)   (None, 760)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 760)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 3044
# =================================================================
# Total params: 2,953,364
# Trainable params: 2,953,364
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 5/5 [==============================] - 7s 912ms/step - loss: 4.9419 - val_loss: 4.5753
# Epoch 2/300
# 5/5 [==============================] - 4s 764ms/step - loss: 4.4356 - val_loss: 3.9911
# Epoch 3/300
# 5/5 [==============================] - 4s 748ms/step - loss: 4.0470 - val_loss: 3.7529
# Epoch 4/300
# 5/5 [==============================] - 4s 753ms/step - loss: 3.7699 - val_loss: 3.5017
# Epoch 5/300
# 5/5 [==============================] - 4s 828ms/step - loss: 3.5530 - val_loss: 3.3092
# Epoch 6/300
# 5/5 [==============================] - 4s 712ms/step - loss: 3.3620 - val_loss: 3.1531
# Epoch 7/300
# 5/5 [==============================] - 3s 678ms/step - loss: 3.1893 - val_loss: 2.9778
# Epoch 8/300
# 5/5 [==============================] - 4s 744ms/step - loss: 3.0302 - val_loss: 2.8429
# Epoch 9/300
# 5/5 [==============================] - 3s 684ms/step - loss: 2.8769 - val_loss: 2.6785
# Epoch 10/300
# 5/5 [==============================] - 4s 803ms/step - loss: 2.7470 - val_loss: 2.5623
# Epoch 11/300
# 5/5 [==============================] - 4s 822ms/step - loss: 2.6022 - val_loss: 2.4194
# Epoch 12/300
# 5/5 [==============================] - 4s 764ms/step - loss: 2.4827 - val_loss: 2.3116
# Epoch 13/300
# 5/5 [==============================] - 4s 747ms/step - loss: 2.3624 - val_loss: 2.1928
# Epoch 14/300
# 5/5 [==============================] - 4s 764ms/step - loss: 2.2461 - val_loss: 2.0946
# Epoch 15/300
# 5/5 [==============================] - 5s 955ms/step - loss: 2.1545 - val_loss: 1.9931
# Epoch 16/300
# 5/5 [==============================] - 4s 822ms/step - loss: 2.0554 - val_loss: 1.9012
# Epoch 17/300
# 5/5 [==============================] - 5s 943ms/step - loss: 1.9528 - val_loss: 1.8139
# Epoch 18/300
# 5/5 [==============================] - 4s 750ms/step - loss: 1.8774 - val_loss: 1.7391
# Epoch 19/300
# 5/5 [==============================] - 4s 788ms/step - loss: 1.7933 - val_loss: 1.6583
# Epoch 20/300
# 5/5 [==============================] - 4s 791ms/step - loss: 1.7182 - val_loss: 1.5925
# Epoch 21/300
# 5/5 [==============================] - 4s 861ms/step - loss: 1.6511 - val_loss: 1.5241
# Epoch 22/300
# 5/5 [==============================] - 4s 838ms/step - loss: 1.5882 - val_loss: 1.4684
# Epoch 23/300
# 5/5 [==============================] - 4s 801ms/step - loss: 1.5242 - val_loss: 1.4158
# Epoch 24/300
# 5/5 [==============================] - 4s 840ms/step - loss: 1.4732 - val_loss: 1.3537
# Epoch 25/300
# 5/5 [==============================] - 4s 796ms/step - loss: 1.4117 - val_loss: 1.3032
# Epoch 26/300
# 5/5 [==============================] - 4s 773ms/step - loss: 1.3537 - val_loss: 1.2501
# Epoch 27/300
# 5/5 [==============================] - 4s 791ms/step - loss: 1.3189 - val_loss: 1.2108
# Epoch 28/300
# 5/5 [==============================] - 4s 811ms/step - loss: 1.2669 - val_loss: 1.1664
# Epoch 29/300
# 5/5 [==============================] - 4s 803ms/step - loss: 1.2348 - val_loss: 1.1275
# Epoch 30/300
# 5/5 [==============================] - 4s 803ms/step - loss: 1.1825 - val_loss: 1.0905
# Epoch 31/300
# 5/5 [==============================] - 4s 828ms/step - loss: 1.1543 - val_loss: 1.0544
# Epoch 32/300
# 5/5 [==============================] - 4s 872ms/step - loss: 1.1116 - val_loss: 1.0209
# Epoch 33/300
# 5/5 [==============================] - 4s 871ms/step - loss: 1.0860 - val_loss: 1.0002
# Epoch 34/300
# 5/5 [==============================] - 5s 975ms/step - loss: 1.0536 - val_loss: 0.9712
# Epoch 35/300
# 5/5 [==============================] - 4s 884ms/step - loss: 1.0261 - val_loss: 0.9394
# Epoch 36/300
# 5/5 [==============================] - 4s 817ms/step - loss: 0.9944 - val_loss: 0.9160
# Epoch 37/300
# 5/5 [==============================] - 4s 794ms/step - loss: 0.9695 - val_loss: 0.8837
# Epoch 38/300
# 5/5 [==============================] - 4s 781ms/step - loss: 0.9428 - val_loss: 0.8651
# Epoch 39/300
# 5/5 [==============================] - 4s 828ms/step - loss: 0.9211 - val_loss: 0.8380
# Epoch 40/300
# 5/5 [==============================] - 4s 834ms/step - loss: 0.8985 - val_loss: 0.8114
# Epoch 41/300
# 5/5 [==============================] - 4s 819ms/step - loss: 0.8757 - val_loss: 0.7914
# Epoch 42/300
# 5/5 [==============================] - 4s 893ms/step - loss: 0.8543 - val_loss: 0.7732
# Epoch 43/300
# 5/5 [==============================] - 4s 848ms/step - loss: 0.8337 - val_loss: 0.7605
# Epoch 44/300
# 5/5 [==============================] - 4s 770ms/step - loss: 0.8132 - val_loss: 0.7365
# Epoch 45/300
# 5/5 [==============================] - 4s 825ms/step - loss: 0.7999 - val_loss: 0.7217
# Epoch 46/300
# 5/5 [==============================] - 4s 825ms/step - loss: 0.7786 - val_loss: 0.7058
# Epoch 47/300
# 5/5 [==============================] - 4s 796ms/step - loss: 0.7649 - val_loss: 0.6969
# Epoch 48/300
# 5/5 [==============================] - 4s 788ms/step - loss: 0.7500 - val_loss: 0.6761
# Epoch 49/300
# 5/5 [==============================] - 4s 772ms/step - loss: 0.7398 - val_loss: 0.6588
# Epoch 50/300
# 5/5 [==============================] - 4s 832ms/step - loss: 0.7178 - val_loss: 0.6474
# Epoch 51/300
# 5/5 [==============================] - 4s 747ms/step - loss: 0.7067 - val_loss: 0.6357
# Epoch 52/300
# 5/5 [==============================] - 4s 800ms/step - loss: 0.6898 - val_loss: 0.6264
# Epoch 53/300
# 5/5 [==============================] - 4s 762ms/step - loss: 0.6844 - val_loss: 0.6118
# Epoch 54/300
# 5/5 [==============================] - 4s 811ms/step - loss: 0.6721 - val_loss: 0.5983
# Epoch 55/300
# 5/5 [==============================] - 4s 813ms/step - loss: 0.6662 - val_loss: 0.5921
# Epoch 56/300
# 5/5 [==============================] - 4s 735ms/step - loss: 0.6476 - val_loss: 0.5850
# Epoch 57/300
# 5/5 [==============================] - 4s 759ms/step - loss: 0.6355 - val_loss: 0.5757
# Epoch 58/300
# 5/5 [==============================] - 3s 698ms/step - loss: 0.6251 - val_loss: 0.5681
# Epoch 59/300
# 5/5 [==============================] - 4s 748ms/step - loss: 0.6297 - val_loss: 0.5551
# Epoch 60/300
# 5/5 [==============================] - 4s 775ms/step - loss: 0.6103 - val_loss: 0.5452
# Epoch 61/300
# 5/5 [==============================] - 4s 824ms/step - loss: 0.5993 - val_loss: 0.5451
# Epoch 62/300
# 5/5 [==============================] - 4s 728ms/step - loss: 0.5908 - val_loss: 0.5371
# Epoch 63/300
# 5/5 [==============================] - 4s 787ms/step - loss: 0.5794 - val_loss: 0.5275
# Epoch 64/300
# 5/5 [==============================] - 4s 828ms/step - loss: 0.5782 - val_loss: 0.5166
# Epoch 65/300
# 5/5 [==============================] - 4s 850ms/step - loss: 0.5590 - val_loss: 0.5050
# Epoch 66/300
# 5/5 [==============================] - 4s 883ms/step - loss: 0.5564 - val_loss: 0.5001
# Epoch 67/300
# 5/5 [==============================] - 4s 906ms/step - loss: 0.5471 - val_loss: 0.4973
# Epoch 68/300
# 5/5 [==============================] - 4s 780ms/step - loss: 0.5408 - val_loss: 0.4899
# Epoch 69/300
# 5/5 [==============================] - 4s 825ms/step - loss: 0.5359 - val_loss: 0.4862
# Epoch 70/300
# 5/5 [==============================] - 4s 796ms/step - loss: 0.5312 - val_loss: 0.4794
# Epoch 71/300
# 5/5 [==============================] - 4s 754ms/step - loss: 0.5263 - val_loss: 0.4642
# Epoch 72/300
# 5/5 [==============================] - 4s 695ms/step - loss: 0.5196 - val_loss: 0.4622
# Epoch 73/300
# 5/5 [==============================] - 4s 752ms/step - loss: 0.5156 - val_loss: 0.4555
# Epoch 74/300
# 5/5 [==============================] - 4s 743ms/step - loss: 0.5027 - val_loss: 0.4527
# Epoch 75/300
# 5/5 [==============================] - 4s 733ms/step - loss: 0.5040 - val_loss: 0.4486
# Epoch 76/300
# 5/5 [==============================] - 4s 734ms/step - loss: 0.4938 - val_loss: 0.4371
# Epoch 77/300
# 5/5 [==============================] - 4s 735ms/step - loss: 0.4934 - val_loss: 0.4334
# Epoch 78/300
# 5/5 [==============================] - 4s 793ms/step - loss: 0.4842 - val_loss: 0.4276
# Epoch 79/300
# 5/5 [==============================] - 4s 827ms/step - loss: 0.4736 - val_loss: 0.4315
# Epoch 80/300
# 5/5 [==============================] - 4s 860ms/step - loss: 0.4733 - val_loss: 0.4330
# Epoch 81/300
# 5/5 [==============================] - 4s 844ms/step - loss: 0.4724 - val_loss: 0.4279
# Epoch 82/300
# 5/5 [==============================] - 4s 881ms/step - loss: 0.4681 - val_loss: 0.4217
# Epoch 83/300
# 5/5 [==============================] - 4s 818ms/step - loss: 0.4622 - val_loss: 0.4145
# Epoch 84/300
# 5/5 [==============================] - 4s 765ms/step - loss: 0.4631 - val_loss: 0.4107
# Epoch 85/300
# 5/5 [==============================] - 4s 825ms/step - loss: 0.4533 - val_loss: 0.4083
# Epoch 86/300
# 5/5 [==============================] - 4s 778ms/step - loss: 0.4511 - val_loss: 0.4013
# Epoch 87/300
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4509 - val_loss: 0.4009
# Epoch 88/300
# 5/5 [==============================] - 4s 785ms/step - loss: 0.4424 - val_loss: 0.3994
# Epoch 89/300
# 5/5 [==============================] - 4s 772ms/step - loss: 0.4374 - val_loss: 0.3911
# Epoch 90/300
# 5/5 [==============================] - 4s 828ms/step - loss: 0.4382 - val_loss: 0.3868
# Epoch 91/300
# 5/5 [==============================] - 4s 776ms/step - loss: 0.4357 - val_loss: 0.3867
# Epoch 92/300
# 5/5 [==============================] - 4s 817ms/step - loss: 0.4263 - val_loss: 0.3851
# Epoch 93/300
# 5/5 [==============================] - 4s 823ms/step - loss: 0.4234 - val_loss: 0.3843
# Epoch 94/300
# 5/5 [==============================] - 4s 805ms/step - loss: 0.4165 - val_loss: 0.3898
# Epoch 95/300
# 5/5 [==============================] - 4s 844ms/step - loss: 0.4190 - val_loss: 0.3825
# Epoch 96/300
# 5/5 [==============================] - 4s 824ms/step - loss: 0.4128 - val_loss: 0.3897
# Epoch 97/300
# 5/5 [==============================] - 4s 748ms/step - loss: 0.4189 - val_loss: 0.3800
# Epoch 98/300
# 5/5 [==============================] - 4s 756ms/step - loss: 0.4122 - val_loss: 0.3703
# Epoch 99/300
# 5/5 [==============================] - 4s 741ms/step - loss: 0.4109 - val_loss: 0.3669
# Epoch 100/300
# 5/5 [==============================] - 4s 727ms/step - loss: 0.4055 - val_loss: 0.3610
# Epoch 101/300
# 5/5 [==============================] - 4s 722ms/step - loss: 0.4063 - val_loss: 0.3598
# Epoch 102/300
# 5/5 [==============================] - 4s 734ms/step - loss: 0.4026 - val_loss: 0.3527
# Epoch 103/300
# 5/5 [==============================] - 4s 766ms/step - loss: 0.3971 - val_loss: 0.3532
# Epoch 104/300
# 5/5 [==============================] - 4s 751ms/step - loss: 0.3909 - val_loss: 0.3595
# Epoch 105/300
# 5/5 [==============================] - 4s 789ms/step - loss: 0.3931 - val_loss: 0.3564
# Epoch 106/300
# 5/5 [==============================] - 4s 764ms/step - loss: 0.3894 - val_loss: 0.3448
# Epoch 107/300
# 5/5 [==============================] - 4s 780ms/step - loss: 0.3897 - val_loss: 0.3436
# Epoch 108/300
# 5/5 [==============================] - 4s 811ms/step - loss: 0.3938 - val_loss: 0.3494
# Epoch 109/300
# 5/5 [==============================] - 4s 815ms/step - loss: 0.3805 - val_loss: 0.3607
# Epoch 110/300
# 5/5 [==============================] - 4s 744ms/step - loss: 0.3803 - val_loss: 0.3453
# Epoch 111/300
# 5/5 [==============================] - 3s 688ms/step - loss: 0.3815 - val_loss: 0.3396
# Epoch 112/300
# 5/5 [==============================] - 3s 675ms/step - loss: 0.3822 - val_loss: 0.3372
# Epoch 113/300
# 5/5 [==============================] - 3s 690ms/step - loss: 0.3709 - val_loss: 0.3383
# Epoch 114/300
# 5/5 [==============================] - 4s 756ms/step - loss: 0.3719 - val_loss: 0.3436
# Epoch 115/300
# 5/5 [==============================] - 3s 687ms/step - loss: 0.3730 - val_loss: 0.3412
# Epoch 116/300
# 5/5 [==============================] - 3s 685ms/step - loss: 0.3701 - val_loss: 0.3338
# Epoch 117/300
# 5/5 [==============================] - 4s 719ms/step - loss: 0.3683 - val_loss: 0.3242
# Epoch 118/300
# 5/5 [==============================] - 3s 705ms/step - loss: 0.3686 - val_loss: 0.3202
# Epoch 119/300
# 5/5 [==============================] - 3s 698ms/step - loss: 0.3715 - val_loss: 0.3278
# Epoch 120/300
# 5/5 [==============================] - 4s 734ms/step - loss: 0.3648 - val_loss: 0.3322
# Epoch 121/300
# 5/5 [==============================] - 4s 763ms/step - loss: 0.3629 - val_loss: 0.3300
# Epoch 122/300
# 5/5 [==============================] - 4s 826ms/step - loss: 0.3544 - val_loss: 0.3231
# Epoch 123/300
# 5/5 [==============================] - 4s 797ms/step - loss: 0.3596 - val_loss: 0.3240
# Epoch 124/300
# 5/5 [==============================] - 4s 777ms/step - loss: 0.3551 - val_loss: 0.3166
# Epoch 125/300
# 5/5 [==============================] - 4s 728ms/step - loss: 0.3581 - val_loss: 0.3256
# Epoch 126/300
# 5/5 [==============================] - 4s 725ms/step - loss: 0.3597 - val_loss: 0.3281
# Epoch 127/300
# 5/5 [==============================] - 4s 746ms/step - loss: 0.3565 - val_loss: 0.3222
# Epoch 128/300
# 5/5 [==============================] - 4s 747ms/step - loss: 0.3556 - val_loss: 0.3122
# Epoch 129/300
# 5/5 [==============================] - 4s 735ms/step - loss: 0.3455 - val_loss: 0.3164
# Epoch 130/300
# 5/5 [==============================] - 3s 700ms/step - loss: 0.3459 - val_loss: 0.3188
# Epoch 131/300
# 5/5 [==============================] - 4s 702ms/step - loss: 0.3492 - val_loss: 0.3220
# Epoch 132/300
# 5/5 [==============================] - 3s 697ms/step - loss: 0.3461 - val_loss: 0.3107
# Epoch 133/300
# 5/5 [==============================] - 4s 716ms/step - loss: 0.3470 - val_loss: 0.3098
# Epoch 134/300
# 5/5 [==============================] - 3s 680ms/step - loss: 0.3441 - val_loss: 0.3065
# Epoch 135/300
# 5/5 [==============================] - 3s 698ms/step - loss: 0.3506 - val_loss: 0.3151
# Epoch 136/300
# 5/5 [==============================] - 4s 774ms/step - loss: 0.3418 - val_loss: 0.3194
# Epoch 137/300
# 5/5 [==============================] - 4s 717ms/step - loss: 0.3480 - val_loss: 0.3100
# Epoch 138/300
# 5/5 [==============================] - 3s 705ms/step - loss: 0.3383 - val_loss: 0.2995
# Epoch 139/300
# 5/5 [==============================] - 3s 705ms/step - loss: 0.3341 - val_loss: 0.3039
# Epoch 140/300
# 5/5 [==============================] - 3s 677ms/step - loss: 0.3437 - val_loss: 0.3189
# Epoch 141/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.3431 - val_loss: 0.3017
# Epoch 142/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.3300 - val_loss: 0.2961
# Epoch 143/300
# 5/5 [==============================] - 4s 725ms/step - loss: 0.3320 - val_loss: 0.3035
# Epoch 144/300
# 5/5 [==============================] - 4s 841ms/step - loss: 0.3370 - val_loss: 0.3022
# Epoch 145/300
# 5/5 [==============================] - 4s 736ms/step - loss: 0.3329 - val_loss: 0.2976
# Epoch 146/300
# 5/5 [==============================] - 4s 769ms/step - loss: 0.3325 - val_loss: 0.2973
# Epoch 147/300
# 5/5 [==============================] - 4s 773ms/step - loss: 0.3290 - val_loss: 0.3022
# Epoch 148/300
# 5/5 [==============================] - 4s 905ms/step - loss: 0.3259 - val_loss: 0.2965
# Epoch 149/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.3314 - val_loss: 0.2950
# Epoch 150/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.3323 - val_loss: 0.2956
# Epoch 151/300
# 5/5 [==============================] - 4s 722ms/step - loss: 0.3263 - val_loss: 0.3001
# Epoch 152/300
# 5/5 [==============================] - 4s 940ms/step - loss: 0.3232 - val_loss: 0.2961
# Epoch 153/300
# 5/5 [==============================] - 4s 817ms/step - loss: 0.3298 - val_loss: 0.2935
# Epoch 154/300
# 5/5 [==============================] - 4s 812ms/step - loss: 0.3219 - val_loss: 0.2965
# Epoch 155/300
# 5/5 [==============================] - 4s 875ms/step - loss: 0.3285 - val_loss: 0.2943
# Epoch 156/300
# 5/5 [==============================] - 4s 832ms/step - loss: 0.3230 - val_loss: 0.2874
# Epoch 157/300
# 5/5 [==============================] - 4s 776ms/step - loss: 0.3238 - val_loss: 0.2944
# Epoch 158/300
# 5/5 [==============================] - 4s 867ms/step - loss: 0.3176 - val_loss: 0.2911
# Epoch 159/300
# 5/5 [==============================] - 4s 847ms/step - loss: 0.3197 - val_loss: 0.2918
# Epoch 160/300
# 5/5 [==============================] - 4s 772ms/step - loss: 0.3214 - val_loss: 0.2884
# Epoch 161/300
# 5/5 [==============================] - 4s 803ms/step - loss: 0.3196 - val_loss: 0.2889
# Epoch 162/300
# 5/5 [==============================] - 4s 816ms/step - loss: 0.3209 - val_loss: 0.2855
# Epoch 163/300
# 5/5 [==============================] - 4s 771ms/step - loss: 0.3185 - val_loss: 0.2882
# Epoch 164/300
# 5/5 [==============================] - 4s 791ms/step - loss: 0.3159 - val_loss: 0.2910
# Epoch 165/300
# 5/5 [==============================] - 4s 763ms/step - loss: 0.3166 - val_loss: 0.2824
# Epoch 166/300
# 5/5 [==============================] - 4s 767ms/step - loss: 0.3120 - val_loss: 0.2871
# Epoch 167/300
# 5/5 [==============================] - 4s 780ms/step - loss: 0.3177 - val_loss: 0.2891
# Epoch 168/300
# 5/5 [==============================] - 4s 785ms/step - loss: 0.3186 - val_loss: 0.2827
# Epoch 169/300
# 5/5 [==============================] - 4s 895ms/step - loss: 0.3182 - val_loss: 0.2854
# Epoch 170/300
# 5/5 [==============================] - 4s 824ms/step - loss: 0.3126 - val_loss: 0.2852
# Epoch 171/300
# 5/5 [==============================] - 4s 788ms/step - loss: 0.3146 - val_loss: 0.2823
# Epoch 172/300
# 5/5 [==============================] - 4s 812ms/step - loss: 0.3111 - val_loss: 0.2812
# Epoch 173/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.3181 - val_loss: 0.2875
# Epoch 174/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.3107 - val_loss: 0.2808
# Epoch 175/300
# 5/5 [==============================] - 4s 847ms/step - loss: 0.3075 - val_loss: 0.2819
# Epoch 176/300
# 5/5 [==============================] - 4s 774ms/step - loss: 0.3094 - val_loss: 0.2850
# Epoch 177/300
# 5/5 [==============================] - 4s 909ms/step - loss: 0.3101 - val_loss: 0.2760
# Epoch 178/300
# 5/5 [==============================] - 4s 837ms/step - loss: 0.3162 - val_loss: 0.2780
# Epoch 179/300
# 5/5 [==============================] - 4s 772ms/step - loss: 0.3066 - val_loss: 0.2824
# Epoch 180/300
# 5/5 [==============================] - 4s 821ms/step - loss: 0.3155 - val_loss: 0.2822
# Epoch 181/300
# 5/5 [==============================] - 4s 743ms/step - loss: 0.3136 - val_loss: 0.2796
# Epoch 182/300
# 5/5 [==============================] - 4s 723ms/step - loss: 0.3119 - val_loss: 0.2865
# Epoch 183/300
# 5/5 [==============================] - 4s 728ms/step - loss: 0.3096 - val_loss: 0.2747
# Epoch 184/300
# 5/5 [==============================] - 4s 903ms/step - loss: 0.3077 - val_loss: 0.2855
# Epoch 185/300
# 5/5 [==============================] - 4s 812ms/step - loss: 0.3120 - val_loss: 0.2790
# Epoch 186/300
# 5/5 [==============================] - 4s 851ms/step - loss: 0.3032 - val_loss: 0.2769
# Epoch 187/300
# 5/5 [==============================] - 4s 803ms/step - loss: 0.3078 - val_loss: 0.2779
# Epoch 188/300
# 5/5 [==============================] - 4s 760ms/step - loss: 0.3099 - val_loss: 0.2755
# Epoch 189/300
# 5/5 [==============================] - 4s 822ms/step - loss: 0.3094 - val_loss: 0.2757
# Epoch 190/300
# 5/5 [==============================] - 4s 776ms/step - loss: 0.3058 - val_loss: 0.2784
# Epoch 191/300
# 5/5 [==============================] - 4s 785ms/step - loss: 0.3002 - val_loss: 0.2713
# Epoch 192/300
# 5/5 [==============================] - 4s 777ms/step - loss: 0.3059 - val_loss: 0.2771
# Epoch 193/300
# 5/5 [==============================] - 4s 813ms/step - loss: 0.3026 - val_loss: 0.2744
# Epoch 194/300
# 5/5 [==============================] - 4s 743ms/step - loss: 0.3015 - val_loss: 0.2704
# Epoch 195/300
# 5/5 [==============================] - 4s 744ms/step - loss: 0.3046 - val_loss: 0.2764
# Epoch 196/300
# 5/5 [==============================] - 4s 832ms/step - loss: 0.3011 - val_loss: 0.2695
# Epoch 197/300
# 5/5 [==============================] - 4s 804ms/step - loss: 0.3096 - val_loss: 0.2819
# Epoch 198/300
# 5/5 [==============================] - 3s 719ms/step - loss: 0.3022 - val_loss: 0.2696
# Epoch 199/300
# 5/5 [==============================] - 4s 761ms/step - loss: 0.3021 - val_loss: 0.2737
# Epoch 200/300
# 5/5 [==============================] - 4s 754ms/step - loss: 0.2968 - val_loss: 0.2740
# Epoch 201/300
# 5/5 [==============================] - 4s 784ms/step - loss: 0.3057 - val_loss: 0.2726
# Epoch 202/300
# 5/5 [==============================] - 4s 868ms/step - loss: 0.3018 - val_loss: 0.2706
# Epoch 203/300
# 5/5 [==============================] - 4s 815ms/step - loss: 0.3003 - val_loss: 0.2678
# Epoch 204/300
# 5/5 [==============================] - 4s 891ms/step - loss: 0.2989 - val_loss: 0.2797
# Epoch 205/300
# 5/5 [==============================] - 4s 776ms/step - loss: 0.2947 - val_loss: 0.2675
# Epoch 206/300
# 5/5 [==============================] - 4s 794ms/step - loss: 0.2986 - val_loss: 0.2734
# Epoch 207/300
# 5/5 [==============================] - 4s 784ms/step - loss: 0.2981 - val_loss: 0.2736
# Epoch 208/300
# 5/5 [==============================] - 5s 976ms/step - loss: 0.3004 - val_loss: 0.2666
# Epoch 209/300
# 5/5 [==============================] - 4s 810ms/step - loss: 0.2970 - val_loss: 0.2714
# Epoch 210/300
# 5/5 [==============================] - 4s 777ms/step - loss: 0.2933 - val_loss: 0.2690
# Epoch 211/300
# 5/5 [==============================] - 4s 732ms/step - loss: 0.3011 - val_loss: 0.2662
# Epoch 212/300
# 5/5 [==============================] - 4s 786ms/step - loss: 0.2955 - val_loss: 0.2728
# Epoch 213/300
# 5/5 [==============================] - 4s 899ms/step - loss: 0.2975 - val_loss: 0.2664
# Epoch 214/300
# 5/5 [==============================] - 5s 996ms/step - loss: 0.2897 - val_loss: 0.2717
# Epoch 215/300
# 5/5 [==============================] - 7s 1s/step - loss: 0.2906 - val_loss: 0.2664
# Epoch 216/300
# 5/5 [==============================] - 6s 1s/step - loss: 0.2948 - val_loss: 0.2668
# Epoch 217/300
# 5/5 [==============================] - 4s 816ms/step - loss: 0.2942 - val_loss: 0.2688
# Epoch 218/300
# 5/5 [==============================] - 4s 922ms/step - loss: 0.2965 - val_loss: 0.2675
# Epoch 219/300
# 5/5 [==============================] - 4s 786ms/step - loss: 0.2891 - val_loss: 0.2694
# Epoch 220/300
# 5/5 [==============================] - 4s 775ms/step - loss: 0.2964 - val_loss: 0.2653
# Epoch 221/300
# 5/5 [==============================] - 4s 795ms/step - loss: 0.2955 - val_loss: 0.2683
# Epoch 222/300
# 5/5 [==============================] - 4s 734ms/step - loss: 0.2953 - val_loss: 0.2627
# Epoch 223/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.2945 - val_loss: 0.2666
# Epoch 224/300
# 5/5 [==============================] - 4s 863ms/step - loss: 0.2941 - val_loss: 0.2662
# Epoch 225/300
# 5/5 [==============================] - 4s 758ms/step - loss: 0.2989 - val_loss: 0.2681
# Epoch 226/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.2942 - val_loss: 0.2663
# Epoch 227/300
# 5/5 [==============================] - 5s 996ms/step - loss: 0.2987 - val_loss: 0.2695
# Epoch 228/300
# 5/5 [==============================] - 4s 735ms/step - loss: 0.2922 - val_loss: 0.2627
# Epoch 229/300
# 5/5 [==============================] - 4s 728ms/step - loss: 0.2922 - val_loss: 0.2651
# Epoch 230/300
# 5/5 [==============================] - 4s 819ms/step - loss: 0.2942 - val_loss: 0.2648
# Epoch 231/300
# 5/5 [==============================] - 4s 821ms/step - loss: 0.2907 - val_loss: 0.2627
# Epoch 232/300
# 5/5 [==============================] - 4s 825ms/step - loss: 0.2903 - val_loss: 0.2663
# Epoch 233/300
# 5/5 [==============================] - 4s 761ms/step - loss: 0.2940 - val_loss: 0.2650
# Epoch 234/300
# 5/5 [==============================] - 4s 840ms/step - loss: 0.2949 - val_loss: 0.2631
# Epoch 235/300
# 5/5 [==============================] - 5s 979ms/step - loss: 0.2910 - val_loss: 0.2642
# Epoch 236/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.2954 - val_loss: 0.2625
# Epoch 237/300
# 5/5 [==============================] - 5s 991ms/step - loss: 0.2908 - val_loss: 0.2638
# Epoch 238/300
# 5/5 [==============================] - 4s 798ms/step - loss: 0.2912 - val_loss: 0.2633
# Epoch 239/300
# 5/5 [==============================] - 4s 742ms/step - loss: 0.2922 - val_loss: 0.2628
# Epoch 240/300
# 5/5 [==============================] - 4s 748ms/step - loss: 0.2928 - val_loss: 0.2617
# Epoch 241/300
# 5/5 [==============================] - 4s 756ms/step - loss: 0.2883 - val_loss: 0.2645
# Epoch 242/300
# 5/5 [==============================] - 4s 825ms/step - loss: 0.2883 - val_loss: 0.2614
# Epoch 243/300
# 5/5 [==============================] - 4s 772ms/step - loss: 0.2943 - val_loss: 0.2622
# Epoch 244/300
# 5/5 [==============================] - 4s 772ms/step - loss: 0.2944 - val_loss: 0.2630
# Epoch 245/300
# 5/5 [==============================] - 4s 759ms/step - loss: 0.2904 - val_loss: 0.2600
# Epoch 246/300
# 5/5 [==============================] - 4s 758ms/step - loss: 0.2857 - val_loss: 0.2637
# Epoch 247/300
# 5/5 [==============================] - 4s 739ms/step - loss: 0.2881 - val_loss: 0.2598
# Epoch 248/300
# 5/5 [==============================] - 4s 739ms/step - loss: 0.2864 - val_loss: 0.2634
# Epoch 249/300
# 5/5 [==============================] - 4s 752ms/step - loss: 0.2869 - val_loss: 0.2617
# Epoch 250/300
# 5/5 [==============================] - 5s 957ms/step - loss: 0.2853 - val_loss: 0.2611
# Epoch 251/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.2901 - val_loss: 0.2610
# Epoch 252/300
# 5/5 [==============================] - 5s 1s/step - loss: 0.2837 - val_loss: 0.2615
# Epoch 253/300
# 5/5 [==============================] - 4s 851ms/step - loss: 0.2845 - val_loss: 0.2614
# Epoch 254/300
# 5/5 [==============================] - 4s 752ms/step - loss: 0.2864 - val_loss: 0.2636
# Epoch 255/300
# 5/5 [==============================] - 4s 722ms/step - loss: 0.2890 - val_loss: 0.2596
# Epoch 256/300
# 5/5 [==============================] - 4s 740ms/step - loss: 0.2835 - val_loss: 0.2603
# Epoch 257/300
# 5/5 [==============================] - 4s 717ms/step - loss: 0.2861 - val_loss: 0.2583
# Epoch 258/300
# 5/5 [==============================] - 4s 722ms/step - loss: 0.2847 - val_loss: 0.2637
# Epoch 259/300
# 5/5 [==============================] - 4s 738ms/step - loss: 0.2877 - val_loss: 0.2566
# Epoch 260/300
# 5/5 [==============================] - 4s 739ms/step - loss: 0.2843 - val_loss: 0.2635
# Epoch 261/300
# 5/5 [==============================] - 4s 814ms/step - loss: 0.2874 - val_loss: 0.2611
# Epoch 262/300
# 5/5 [==============================] - 4s 787ms/step - loss: 0.2835 - val_loss: 0.2566
# Epoch 263/300
# 5/5 [==============================] - 4s 781ms/step - loss: 0.2879 - val_loss: 0.2627
# Epoch 264/300
# 5/5 [==============================] - 4s 735ms/step - loss: 0.2854 - val_loss: 0.2574
# Epoch 265/300
# 5/5 [==============================] - 4s 744ms/step - loss: 0.2826 - val_loss: 0.2607
# Epoch 266/300
# 5/5 [==============================] - 4s 738ms/step - loss: 0.2888 - val_loss: 0.2578
# Epoch 267/300
# 5/5 [==============================] - 4s 738ms/step - loss: 0.2853 - val_loss: 0.2620
# Epoch 268/300
# 5/5 [==============================] - 4s 745ms/step - loss: 0.2878 - val_loss: 0.2578
# Epoch 269/300
# 5/5 [==============================] - 4s 729ms/step - loss: 0.2905 - val_loss: 0.2619
# Epoch 270/300
# 5/5 [==============================] - 4s 734ms/step - loss: 0.2846 - val_loss: 0.2578
# Epoch 271/300
# 5/5 [==============================] - 4s 735ms/step - loss: 0.2832 - val_loss: 0.2612
# Epoch 272/300
# 5/5 [==============================] - 4s 795ms/step - loss: 0.2835 - val_loss: 0.2584

# %%
""" Training history plot. """

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
#plt.ylim(0.6,1)
plt.show()
plt.clf()

# %%
""" Save model. """
model.save("models/mass_reco_narrow_mse_loss_btags")
# Out:
# INFO:tensorflow:Assets written to: models/mass_reco_narrow_mse_loss_btags/assets
# 2022-01-04 10:46:03.355510: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %%
""" Pyplot histogram. """

from scipy.optimize import curve_fit
from scipy.stats import crystalball, norm

ttH_eval_generator = DataGenerator(np.concatenate((X_y_test_ttH[:,:-10], X_y_test_ttH[:,-6:]), axis = 1), X_y_test_ttH[:,-10:-6], n_features = num_features, batch_size=64, shuffle=False, augmentation = False, ceil = True)
ttZ_eval_generator = DataGenerator(np.concatenate((X_y_test_ttZ[:,:-10], X_y_test_ttZ[:,-6:]), axis = 1), X_y_test_ttZ[:,-10:-6], n_features = num_features, batch_size=64, shuffle=False, augmentation = False, ceil = True)

ttH_y_pred = model.predict(ttH_eval_generator)
X_y = ttH_eval_generator.get_all()
ttH_X_eval = X_y[0]
ttH_y_true = X_y[1]

ttZ_y_pred = model.predict(ttZ_eval_generator)
X_y = ttZ_eval_generator.get_all()
ttZ_X_eval = X_y[0]
ttZ_y_true = X_y[1]


""" Scale in the opposite direction, to get the mass in MeV. """
with open("scaler_params/y_scaler_higgs_mse_btags.csv") as f:
    scaler_params = np.loadtxt(f, delimiter=",")
    y_scaler = scaler_params[0:2]

ttH_y_true = ttH_y_true * y_scaler[1] + y_scaler[0]
ttH_y_pred = ttH_y_pred * y_scaler[1] + y_scaler[0]

ttZ_y_true = ttZ_y_true * y_scaler[1] + y_scaler[0]
ttZ_y_pred = ttZ_y_pred * y_scaler[1] + y_scaler[0]

with open("scaler_params/X_scaler_mass_reco_narrow_btags.csv") as f:
    scaler_params = np.loadtxt(f, delimiter=",")
    X_scaler = scaler_params[0:2,:]

ttH_X_eval = ttH_X_eval * X_scaler[1] + X_scaler[0]
ttZ_X_eval = ttZ_X_eval * X_scaler[1] + X_scaler[0]

predicted_higgs_masses = []
predicted_Z_masses = []

VIS_TAU_HADR_INDEX = 12
VIS_TAU_LEP_INDEX = 28

""" Compute the masses from the predicted four-vectors. """
for i in range(len(ttH_X_eval)):

    X_eval_sample = ttH_X_eval[i]
    y_pred_sample = ttH_y_pred[i]
    y_true_sample = ttH_y_true[i]

    predicted_higgs = TLorentzVector(y_pred_sample[0],y_pred_sample[1],y_pred_sample[2],y_pred_sample[3])

    predicted_higgs_masses.append(predicted_higgs.Mag()/1000)

for i in range(len(ttZ_X_eval)):

    X_eval_sample = ttZ_X_eval[i]
    y_pred_sample = ttZ_y_pred[i]
    y_true_sample = ttZ_y_true[i]

    predicted_Z = TLorentzVector(y_pred_sample[0],y_pred_sample[1],y_pred_sample[2],y_pred_sample[3])

    predicted_Z_masses.append(predicted_Z.Mag()/1000)

plt.figure(figsize=(12,8))

n, bins, patches = plt.hist(predicted_higgs_masses, bins=np.linspace(70,200,100), alpha = 0.5, density = True, color='blue')
centers = (0.5*(bins[1:]+bins[:-1]))
mean,std = norm.fit(predicted_higgs_masses)
p0 = [mean, std]
pars1, cov = curve_fit(lambda x, mu, sig : norm.pdf(x, loc=mu, scale=sig), centers, n, p0=p0)
plt.plot(centers, norm.pdf(centers,*pars1), 'r--',linewidth = 2, label='fit before') 
plt.annotate("Gaussian fit ttH" "\n" r'$\mu=%.3f$' "\n" r'$\sigma=%.3f$' % (pars1[0], pars1[1]), xy=(0, 1), xytext=(20, -12), va='top',
	             xycoords='axes fraction', textcoords='offset points')

n, bins, patches = plt.hist(predicted_Z_masses, bins=np.linspace(70,200,100), alpha = 0.5, density = True, color='orange')
centers = (0.5*(bins[1:]+bins[:-1]))
mean,std = norm.fit(predicted_Z_masses)
p0 = [mean, std]
pars2, cov = curve_fit(lambda x, mu, sig : norm.pdf(x, loc=mu, scale=sig), centers, n, p0=p0)
plt.plot(centers, norm.pdf(centers,*pars2), 'r--',linewidth = 2, label='fit before') 
plt.annotate("Gaussian fit ttZ" "\n" r'$\mu=%.3f$' "\n" r'$\sigma=%.3f$' % (pars2[0], pars2[1]), xy=(0, 1), xytext=(20, -90), va='top',
	             xycoords='axes fraction', textcoords='offset points')

plt.axvline(125,color='blue', linestyle='dashed')
plt.axvline(91.19,color='orange', linestyle='dashed')
plt.title("Mass distribution.\n Single value mass NN output for ttH, ttZ, ttW and tt.")
plt.xlabel("Mass [GeV]")
plt.ylabel("Density")
plt.legend(["fit","fit","125 GeV","91.19 GeV","ttH","ttZ"])
plt.grid()
plt.savefig("figures/mass_histo_narrow_pyplot_mse_loss_btags.pdf")

plt.show()

print(np.mean(predicted_higgs_masses), np.std(predicted_higgs_masses))
# Out:
# 144.04830227830402 31.633117185867206

# %%
""" Separation curve. """

min_mass = np.min(np.concatenate((predicted_higgs_masses, predicted_Z_masses)))
max_mass = np.max(np.concatenate((predicted_higgs_masses, predicted_Z_masses)))

bg_weight = (len(predicted_Z_masses)+len(predicted_higgs_masses))/2/len(predicted_Z_masses)
h_weight = (len(predicted_Z_masses)+len(predicted_higgs_masses))/2/len(predicted_higgs_masses)
print(h_weight)
print(bg_weight)

n_steps = 5000
step_size = (max_mass-min_mass)/n_steps
current_divider = min_mass

correct_h = np.zeros((n_steps))
correct_bg = np.zeros((n_steps))

incorrect_h = np.zeros((n_steps))
incorrect_bg = np.zeros((n_steps))

steps = np.zeros((n_steps))

for i in range(n_steps):

    current_divider = min_mass+i*step_size
    steps[i] = current_divider

    for h_mass in predicted_higgs_masses:
        if h_mass < current_divider:
            incorrect_h[i] += 1
        else:
            correct_h[i] += 1

    for z_mass in predicted_Z_masses:
        if z_mass < current_divider:
            correct_bg[i] += 1
        else:
            incorrect_bg[i] += 1

steps = steps/5000
correct_h /= (len(predicted_higgs_masses)+len(predicted_Z_masses))/100
correct_bg /= (len(predicted_higgs_masses)+len(predicted_Z_masses))/100
plt.figure(figsize=(12,8))
plt.plot(steps, correct_h, linewidth=3, color='blue')
plt.plot(steps, correct_bg, linewidth=3, color='orange')
plt.plot(steps, h_weight*correct_h + bg_weight*correct_bg, linewidth=3, color='magenta')
plt.title("Mass reconstruction separation curve - NN")
plt.xlabel("separation mass [GeV]")
plt.ylabel("percentage correct [%]")
plt.legend(["correct Higgs","correct background","weighted correct total"])
plt.grid()
plt.savefig("figures/mass_histo_narrow_separation_mse_loss_btags.pdf")
plt.show()
print(np.max(h_weight*correct_h + bg_weight*correct_bg))
# Out:
# 0.8
# 1.3333333333333333
# 56.2534435261708

# %%
""" ROOT histogram. """
import atlasplots as aplt
import root_numpy
from ROOT import TF1, TLine

aplt.set_atlas_style()

H_line = TLine(125.18,0,125.18,1000)
H_line.SetLineStyle(9)
H_line.SetLineWidth(3)
Z_line = TLine(91.19,0,91.19,1000)
Z_line.SetLineStyle(9)
Z_line.SetLineWidth(3)

gauss_fit_1 = TF1("gauss_fit_1","gaus(0)",70,200)
gauss_fit_1.SetParameters(1, 1, 1)

gauss_fit_2 = TF1("gauss_fit_2","gaus(0)",70,200)
gauss_fit_2.SetParameters(1, 1, 1)

ttH = root.TH1F("ttH","",20,70,200)
root_numpy.fill_hist(ttH, predicted_higgs_masses)

weights = np.ones(len(predicted_Z_masses))*(len(predicted_higgs_masses)/len(predicted_Z_masses))

ttZ = root.TH1F("ttZ","",20,70,200)
root_numpy.fill_hist(ttZ, predicted_Z_masses, weights)

fig, ax = aplt.subplots(1, 1)

ttH.Fit("gauss_fit_2","0")
gauss_fit_2.SetNpx(1000)
#ax.plot(gauss_fit_2, label="Fit", labelfmt="L", linecolor=root.kRed+1, linewidth=3)

ttZ.Fit("gauss_fit_1","0")
gauss_fit_1.SetNpx(1000)
#ax.plot(gauss_fit_1, label=None, labelfmt="L", linecolor=root.kRed+1, linewidth=3)

ttH_fit = ttH.GetFunction("gauss_fit_2")
print(ttH_fit.GetParameter(0))
print(ttH_fit.GetParameter(1))
print(ttH_fit.GetParameter(2))
ax.plot(H_line, linecolor='black', label=None, labelfmt="L")
ax.plot(Z_line, linecolor='black', label=None, labelfmt="L")
ax.plot(ttH, linecolor='blue', linewidth=3, label="ttH", labelfmt="L")
ax.plot(ttZ, linecolor=807, linewidth=3, label="ttZ", labelfmt="L")
ax.set_xlim(70, 200)
ax.set_ylim(0, 800)
ax.set_xlabel("Mass [GeV]")
ax.set_ylabel("Events")
ax.add_margins(top=0.15)
ax.legend(loc=(0.77, 0.7, 0.95, 0.92))
fig.savefig("figures/mass_histo_narrow_root_mse_loss_btags.pdf")
# Out:
# Applying ATLAS style settings
# `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 717.270474772171
# 144.8452056173269
# 5.772535534702401
#  FCN=187.288 FROM MIGRAD    STATUS=CONVERGED      88 CALLS          89 TOTAL
#                      EDM=1.11792e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.17270e+02   2.80901e+01   1.20270e-01  -2.26764e-06
#    2  Mean         1.44845e+02   1.56511e-01   9.67885e-04   1.34345e-04
#    3  Sigma        5.77254e+00   1.73804e-01   3.04313e-05  -9.69359e-03
#  FCN=125.285 FROM MIGRAD    STATUS=CONVERGED      90 CALLS          91 TOTAL
#                      EDM=6.07688e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     6.67328e+02   3.36968e+01   1.20346e-01  -3.63530e-05
#    2  Mean         1.43171e+02   1.97721e-01   1.08159e-03   3.13898e-03
#    3  Sigma        5.99522e+00   2.29710e-01   3.20915e-05  -5.97554e-02
# Info in <TCanvas::Print>: pdf file figures/mass_histo_narrow_root_mse_loss_btags.pdf has been created
